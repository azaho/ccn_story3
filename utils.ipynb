# %%
indices = list(range(0, 20))
print("conda deactivate")
for i in indices: print(f"python3 task_and_training_backprop_withdistractor.py --random {i} &")
for i in indices: print(f"python3 task_and_training_hdgating.py --random {i} &")
for i in indices: print(f"python3 task_and_training_hdgating_inversion.py --random {i} &")
for i in indices: print(f"python3 task_and_training_hdinversion.py --random {i} &")
for i in indices: print(f"python3 task_and_training_hdrchange.py --random {i} --shift_amount 120 &")
for i in range(20, 30): print(f"python3 task_and_training_backprop_withdistractor.py --random {i} &")
print("wait")
# Out:
# conda deactivate
# python3 task_and_training_backprop_withdistractor.py --random 0 &
# python3 task_and_training_backprop_withdistractor.py --random 1 &
# python3 task_and_training_backprop_withdistractor.py --random 2 &
# python3 task_and_training_backprop_withdistractor.py --random 3 &
# python3 task_and_training_backprop_withdistractor.py --random 4 &
# python3 task_and_training_backprop_withdistractor.py --random 5 &
# python3 task_and_training_backprop_withdistractor.py --random 6 &
# python3 task_and_training_backprop_withdistractor.py --random 7 &
# python3 task_and_training_backprop_withdistractor.py --random 8 &
# python3 task_and_training_backprop_withdistractor.py --random 9 &
# python3 task_and_training_backprop_withdistractor.py --random 10 &
# python3 task_and_training_backprop_withdistractor.py --random 11 &
# python3 task_and_training_backprop_withdistractor.py --random 12 &
# python3 task_and_training_backprop_withdistractor.py --random 13 &
# ...
